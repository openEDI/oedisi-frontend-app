# %% [markdown]
# # Sliding Window Oscillation Detection (SWOD) — Analysis
#
# This notebook post-processes and analyzes EMT simulation results from the PNNL SWOD federate.

# %%
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
from pnnl_emt_swod.plotting import plot_results_from_feather

# DATA_DIR will be set automatically when copied to a run
DATA_DIR = r""

# %%
build_dir = Path(DATA_DIR) if DATA_DIR else Path(".").resolve()
run_dir = build_dir.parent if build_dir.name == "build" else build_dir
outputs_dir = run_dir / "outputs"
if not outputs_dir.exists():
    outputs_dir = build_dir

figures = plot_results_from_feather(outputs_dir)
for fig in figures:
    plt.show()
