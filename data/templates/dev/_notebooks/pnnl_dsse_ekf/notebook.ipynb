# %% [markdown]
# # PNNL DSSE EKF — Analysis
#
# Analysis notebook for Dynamic State Estimation (EKF) simulation outputs.

# %%
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
import pyarrow.feather as pf

# DATA_DIR will be set automatically when copied to a run
DATA_DIR = r""

# %%
data_dir = Path(DATA_DIR) if DATA_DIR else Path(".").resolve()
feather_files = list(data_dir.glob("*.feather"))
print(f"Found {len(feather_files)} dataset files:")
for f in sorted(feather_files):
    df = pd.read_feather(f)
    print(f" - {f.name}: shape {df.shape}")
